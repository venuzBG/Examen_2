# %%
# raiz b**2 - 4*a*c
import math
import numpy as np
a = 1/3
b = -123/4
c = 1/6
y = b**2 - 4*a*c

print(y)

sqrt_y = math.sqrt(y)

print(sqrt_y)

t = 62.0677

x1 = (-b + t) / (2*a)
x2 = (-b - t) / (2*a)

print(x1)
print(x2)

x1_real = -0.016107237
x2_real = -62.083893


# Error relativo
error_relativo1 = abs(x1_real - x1) / abs(x1_real)
error_relativo2 = abs(x2_real - x2) / abs(x2_real)
print(error_relativo1)
print(error_relativo2)

x1 = (2*c) / (-b - t)
x2 = (2*c) / (-b + t)

print(x1)
print(x2)

x1 = -0.0161
x2 = -62.9195
# Error relativo
error_relativo1 = abs(x1_real - x1) / abs(x1_real)
error_relativo2 = abs(x2_real - x2) / abs(x2_real)
print(error_relativo1)
print(error_relativo2)
# Out:
# 3852.4100000000003
# 62.06778552518207
# -0.016149999999999665
# -62.08385
# 0.00265489357359457
# 6.926112060196076e-07
# -0.016107248503435274
# -61.91950464396413
# 0.00044930114333080316
# 0.013459320278127468

# %%
import math
import numpy as np
a = 0.3333
b = -123/4
c = 0.1667
y = b**2 - 4*a*c

print(y)

y = 945.3403
sqrt_y = math.sqrt(y)

print(sqrt_y)

t = 30.7463

# Solo tome 4 cifras significativas para t, lo que afecta el resultado de x1 y x2
x1 = (-b + t) / (2*a)
x2 = (-b - t) / (2*a)

print(x1)
print(x2)

x1_real = 92.24458
x2_real = 0.0054203727

x1 = 92.2536
x2 = 0.00555
# Error relativo
error_relativo1 = abs(x1_real - x1) / abs(x1_real)
error_relativo2 = abs(x2_real - x2) / abs(x2_real)
print(error_relativo1)
print(error_relativo2)
# Out:
# 945.34025556
# 30.746386779587613
# 92.25367536753677
# 0.005550555055503274
# 9.778352289106513e-05
# 0.023914831539167018

# %%
# Resolver

10**-4 < 13/2**n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Resolver
# ----> 3 10**-4 < 13/2**n < 0.01
#
# NameError: name 'n' is not defined

# %%
# Metdo de newton para x= 0 y x = 3

import math
def f(x, d):
    return x**3 - 5*x**2 - 3*x + d
def f_prime(x):
    return 3*x**2 - 10*x - 3
def newton_method(x0, d, tol=1e-6, max_iter=100):
    x = x0
    for i in range(max_iter):
        fx = f(x, d)
        fx_prime = f_prime(x)
        if fx_prime == 0:  # Evitar división por cero
            print("Derivada es cero. No se puede continuar.")
            return None
        x_new = x - fx / fx_prime  # Actualización de Newton
        if abs(x_new - x) < tol:  # Verificar convergencia
            print(f"Convergencia alcanzada en {i+1} iteraciones.")
            return x_new
        x = x_new
    print("Número máximo de iteraciones alcanzado sin convergencia.")
    return x

x = newton_method(0, 3)
print(f"Raíz encontrada cerca de x=0: {x}")

# Valor de d para el cual x=3 es raíz
d = 3**3 - 5*3**2 - 3*3
print(f"Valor de d para el cual x=3 es raíz: {d}")
# Out:
# Convergencia alcanzada en 5 iteraciones.
# Raíz encontrada cerca de x=0: 0.5505102572169089
# Valor de d para el cual x=3 es raíz: -27

# %%
# Metdo de newton para x= 0 y x = 3

import math
def f(x, d):
    return x**3 - x**2 - 5*x + d
def f_prime(x):
    return 3*x**2 - 2*x - 5
def newton_method(x0, d, tol=1e-6, max_iter=100):
    x = x0
    for i in range(max_iter):
        fx = f(x, d)
        fx_prime = f_prime(x)
        if fx_prime == 0:  # Evitar división por cero
            print("Derivada es cero. No se puede continuar.")
            return None
        x_new = x - fx / fx_prime  # Actualización de Newton
        if abs(x_new - x) < tol:  # Verificar convergencia
            print(f"Convergencia alcanzada en {i+1} iteraciones.")
            return x_new
        x = x_new
    print("Número máximo de iteraciones alcanzado sin convergencia.")
    return x

x = newton_method(0, 2)
print(f"Raíz encontrada cerca de x=0: {x}")

# Valor de d para el cual x=3 es raíz
d = 3*x**2 - 2*x - 5
print(f"Valor de d para el cual x=3 es raíz: {d}")
# Out:
# Convergencia alcanzada en 4 iteraciones.
# Raíz encontrada cerca de x=0: 0.38196601125010515
# Valor de d para el cual x=3 es raíz: -5.326237921249264
